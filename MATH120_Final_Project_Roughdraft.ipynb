# %% [markdown]
# <a href="https://colab.research.google.com/github/haydenmclemore-fresnost/math120_final_project/blob/main/MATH120_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # California Water Quality Analysis – Final Project
# This notebook analyzes selected water quality measurements from the California Department of Water Resources (DWR).
# The goal is to clean the data, merge it with station information, and answer a few basic questions using tools from class.

# %% [markdown]
# ## Environment Setup

# %%
from google.colab import drive
drive.mount('/content/drive')

DATA_DIR = "/content/drive/MyDrive/MATH120_Final_Project"
stations_path = f"{DATA_DIR}/stations.csv"
field_path = f"{DATA_DIR}/field_results.csv"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

pd.set_option("display.max_columns", 50)

# %% [markdown]
# ## Load Data

# %%
stations = pd.read_csv(stations_path)
field = pd.read_csv(field_path, nrows=200000)  # sample for speed

stations.head(), field.head()
# Out:
# /tmp/ipython-input-781344394.py:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   field = pd.read_csv(field_path, nrows=200000)  # sample for speed
# (   _id  station_id     station_name         full_station_name station_number station_type  latitude  longitude  \
#  0    1       47023  Frank Sieferman  Frank Sieferman New Well  01N01E01A001M  Groundwater   33.0000  -121.0000
#  1    2        6134    01N01E33K001M             01N01E33K001M  01N01E33K001M  Groundwater   37.8868  -121.8682
#  2    3        6135    01N01W03N001M             01N01W03N001M  01N01W03N001M  Groundwater   37.9583  -121.9669
#  3    4        6136    01N01W04A001M             01N01W04A001M  01N01W04A001M  Groundwater   37.9663  -121.9734
#  4    5        6137    01N01W07K001M             01N01W07K001M  01N01W07K001M  Groundwater   37.9460  -122.0155
#
#      county_name  sample_count      sample_date_min      sample_date_max
#  0          Yolo             1  2008-06-23T15:00:00  2008-06-23T15:00:00
#  1  Contra Costa             1  1981-05-20T13:45:00  1981-05-20T13:45:00
#  2  Contra Costa             9  1974-07-23T15:15:00  1990-08-16T12:15:00
#  3  Contra Costa             9  1972-08-04T15:00:00  1989-09-15T08:00:00
#  4  Contra Costa             9  1973-08-03T09:30:00  1989-09-15T09:15:00  ,
#     _id  station_id          station_name station_number                      full_station_name   station_type  \
#  0    1          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
#  1    2          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
#  2    3          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
#  3    4          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
#  4    5          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
#
#     latitude  longitude                         status county_name  sample_code          sample_date  sample_depth  \
#  0   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001  1968-01-04T07:45:00           1.0
#  1   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001  1968-01-04T07:45:00           1.0
#  2   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001  1968-01-04T07:45:00           1.0
#  3   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001  1968-01-04T07:45:00           1.0
#  4   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0268A0006  1968-02-01T08:10:00           1.0
#
#    sample_depth_units anl_data_type              parameter  fdr_result fdr_text_result fdr_date_result  \
#  0               Feet           NaN        DissolvedOxygen         9.2             NaN             NaN
#  1               Feet           NaN  ElectricalConductance       515.0             NaN             NaN
#  2               Feet           NaN       WaterTemperature         6.7             NaN             NaN
#  3               Feet           NaN                     pH         7.3             NaN             NaN
#  4               Feet           NaN        DissolvedOxygen         9.7             NaN             NaN
#
#     fdr_reporting_limit  uns_name                   mth_name fdr_footnote
#  0                  0.2      mg/L          EPA 360.2 (Field)          NaN
#  1                  1.0     uS/cm  Std Method 2510-B (Field)          NaN
#  2                  0.1        °C          EPA 170.1 (Field)          NaN
#  3                  0.1  pH Units          EPA 150.1 (Field)          NaN
#  4                  0.2      mg/L          EPA 360.2 (Field)          NaN  )

# %% [markdown]
# ## Clean and Standardize Columns

# %%
# We don't really need to rename anything except create a 'result' column

# Make a numeric result column from fdr_result
field["result"] = field["fdr_result"]

# Ensure sample_date is datetime
field["sample_date"] = pd.to_datetime(field["sample_date"], errors="coerce")

field.head()
# Out:
#    _id  station_id          station_name station_number                      full_station_name   station_type  \
# 0    1          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 1    2          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 2    3          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 3    4          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4    5          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
#
#    latitude  longitude                         status county_name  sample_code         sample_date  sample_depth  \
# 0   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00           1.0
# 1   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00           1.0
# 2   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00           1.0
# 3   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00           1.0
# 4   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0268A0006 1968-02-01 08:10:00           1.0
#
#   sample_depth_units anl_data_type              parameter  fdr_result fdr_text_result fdr_date_result  \
# 0               Feet           NaN        DissolvedOxygen         9.2             NaN             NaN
# 1               Feet           NaN  ElectricalConductance       515.0             NaN             NaN
# 2               Feet           NaN       WaterTemperature         6.7             NaN             NaN
# 3               Feet           NaN                     pH         7.3             NaN             NaN
# 4               Feet           NaN        DissolvedOxygen         9.7             NaN             NaN
#
#    fdr_reporting_limit  uns_name                   mth_name fdr_footnote  result
# 0                  0.2      mg/L          EPA 360.2 (Field)          NaN     9.2
# 1                  1.0     uS/cm  Std Method 2510-B (Field)          NaN   515.0
# 2                  0.1        °C          EPA 170.1 (Field)          NaN     6.7
# 3                  0.1  pH Units          EPA 150.1 (Field)          NaN     7.3
# 4                  0.2      mg/L          EPA 360.2 (Field)          NaN     9.7

# %% [markdown]
# ## Filter to Selected Water Quality Parameters

# %%
params = ["pH", "DissolvedOxygen", "ElectricalConductance"]

field_sub = field[field["parameter"].isin(params)]
field_sub.head()
# Out:
#    _id  station_id          station_name station_number                      full_station_name   station_type  \
# 0    1          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 1    2          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 3    4          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4    5          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 5    6          12  H.O. Banks Headworks       KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
#
#    latitude  longitude                         status county_name  sample_code         sample_date  sample_depth  \
# 0   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00           1.0
# 1   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00           1.0
# 3   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00           1.0
# 4   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0268A0006 1968-02-01 08:10:00           1.0
# 5   37.8019  -121.6203  Public, Review Status Unknown     Alameda  OM0268A0006 1968-02-01 08:10:00           1.0
#
#   sample_depth_units anl_data_type              parameter  fdr_result fdr_text_result fdr_date_result  \
# 0               Feet           NaN        DissolvedOxygen         9.2             NaN             NaN
# 1               Feet           NaN  ElectricalConductance       515.0             NaN             NaN
# 3               Feet           NaN                     pH         7.3             NaN             NaN
# 4               Feet           NaN        DissolvedOxygen         9.7             NaN             NaN
# 5               Feet           NaN  ElectricalConductance       720.0             NaN             NaN
#
#    fdr_reporting_limit  uns_name                   mth_name fdr_footnote  result
# 0                  0.2      mg/L          EPA 360.2 (Field)          NaN     9.2
# 1                  1.0     uS/cm  Std Method 2510-B (Field)          NaN   515.0
# 3                  0.1  pH Units          EPA 150.1 (Field)          NaN     7.3
# 4                  0.2      mg/L          EPA 360.2 (Field)          NaN     9.7
# 5                  1.0     uS/cm  Std Method 2510-B (Field)          NaN   720.0

# %% [markdown]
# ## Merge Field Data With Station Metadata

# %%
merged = field_sub.merge(stations, on="station_id", how="left")
merged.head()
# Out:
#    _id_x  station_id        station_name_x station_number_x                    full_station_name_x station_type_x  \
# 0      1          12  H.O. Banks Headworks         KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 1      2          12  H.O. Banks Headworks         KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 2      4          12  H.O. Banks Headworks         KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 3      5          12  H.O. Banks Headworks         KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
# 4      6          12  H.O. Banks Headworks         KA000331  Delta P.P. Headworks at H.O. Banks PP  Surface Water
#
#    latitude_x  longitude_x                         status county_name_x  sample_code         sample_date  \
# 0     37.8019    -121.6203  Public, Review Status Unknown       Alameda  OM0168A0001 1968-01-04 07:45:00
# 1     37.8019    -121.6203  Public, Review Status Unknown       Alameda  OM0168A0001 1968-01-04 07:45:00
# 2     37.8019    -121.6203  Public, Review Status Unknown       Alameda  OM0168A0001 1968-01-04 07:45:00
# 3     37.8019    -121.6203  Public, Review Status Unknown       Alameda  OM0268A0006 1968-02-01 08:10:00
# 4     37.8019    -121.6203  Public, Review Status Unknown       Alameda  OM0268A0006 1968-02-01 08:10:00
#
#    sample_depth sample_depth_units anl_data_type              parameter  fdr_result fdr_text_result fdr_date_result  \
# 0           1.0               Feet           NaN        DissolvedOxygen         9.2             NaN             NaN
# 1           1.0               Feet           NaN  ElectricalConductance       515.0             NaN             NaN
# 2           1.0               Feet           NaN                     pH         7.3             NaN             NaN
# 3           1.0               Feet           NaN        DissolvedOxygen         9.7             NaN             NaN
# 4           1.0               Feet           NaN  ElectricalConductance       720.0             NaN             NaN
#
#    fdr_reporting_limit  uns_name                   mth_name fdr_footnote  result    _id_y        station_name_y  \
# 0                  0.2      mg/L          EPA 360.2 (Field)          NaN     9.2  43682.0  H.O. Banks Headworks
# 1                  1.0     uS/cm  Std Method 2510-B (Field)          NaN   515.0  43682.0  H.O. Banks Headworks
# 2                  0.1  pH Units          EPA 150.1 (Field)          NaN     7.3  43682.0  H.O. Banks Headworks
# 3                  0.2      mg/L          EPA 360.2 (Field)          NaN     9.7  43682.0  H.O. Banks Headworks
# 4                  1.0     uS/cm  Std Method 2510-B (Field)          NaN   720.0  43682.0  H.O. Banks Headworks
#
#                      full_station_name_y station_number_y station_type_y  latitude_y  longitude_y county_name_y  \
# 0  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water     37.8019    -121.6203       Alameda
# 1  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water     37.8019    -121.6203       Alameda
# 2  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water     37.8019    -121.6203       Alameda
# 3  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water     37.8019    -121.6203       Alameda
# 4  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water     37.8019    -121.6203       Alameda
#
#    sample_count      sample_date_min      sample_date_max
# 0        1720.0  1960-10-16T07:25:00  2025-10-21T11:35:00
# 1        1720.0  1960-10-16T07:25:00  2025-10-21T11:35:00
# 2        1720.0  1960-10-16T07:25:00  2025-10-21T11:35:00
# 3        1720.0  1960-10-16T07:25:00  2025-10-21T11:35:00
# 4        1720.0  1960-10-16T07:25:00  2025-10-21T11:35:00

# %% [markdown]
# ## Q1: Average Values by Station

# %%
station_summary = (
    merged.groupby(["station_id", "parameter"], as_index=False)
    .agg(avg=("result", "mean"), count=("result", "count"))
)

station_summary.head()
# Out:
#    station_id              parameter         avg  count
# 0           9        DissolvedOxygen    8.774684    158
# 1           9                     pH    7.541829    164
# 2          10        DissolvedOxygen    8.633507    767
# 3          10  ElectricalConductance  470.948718     39
# 4          10                     pH    7.787925    800

# %% [markdown]
# ## Q2: Trend Over Time (Example Station)

# %%
merged = merged.dropna(subset=["sample_date"])
merged["year"] = merged["sample_date"].dt.year

do_data = merged[merged["parameter"] == "DissolvedOxygen"]

do_data["station_id"].value_counts().head()
# Out:
# station_id
# 12       1054
# 45935    1024
# 45929     978
# 10        767
# 45938     749
# Name: count, dtype: int64

# %%
top_station = do_data["station_id"].value_counts().idxmax()
top_station

yearly = (
    do_data[do_data["station_id"] == top_station]
    .groupby("year", as_index=False)
    .agg(avg=("result", "mean"))
)

px.line(yearly, x="year", y="avg", title=f"Dissolved Oxygen Over Time (Station {top_station})")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="db853118-27f3-441d-9dd3-b38194c5e058" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db853118-27f3-441d-9dd3-b38194c5e058")) {                    Plotly.newPlot(                        "db853118-27f3-441d-9dd3-b38194c5e058",                        [{"hovertemplate":"year=%{x}\u003cbr\u003eavg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[8.175675675675675,8.348936170212765,8.784615384615385,8.763636363636364,8.983333333333333,9.018181818181818,9.028571428571428,8.838461538461539,9.583333333333334,10.786666666666667,10.1,8.923076923076923,10.058333333333334,9.091666666666667,9.222222222222221,8.670370370370371,9.36216216216216,9.104,8.98695652173913,9.458333333333334,9.152000000000001,9.463636363636365,8.735,8.723333333333333,8.718181818181819,8.353333333333333,8.765384615384615,8.347999999999999,8.484827586206897,8.39,8.6,9.236363636363636,9.07,8.3375,8.489999999999998,7.8500000000000005,8.27142857142857,77.47500000000001,8.385714285714286,8.666666666666666,9.166666666666666,8.96,9.175217391304347,9.212916666666667,9.279166666666667,10.225,9.008333333333333,9.56,9.454545454545455,8.316666666666666,7.483333333333333,8.057142857142857,7.75,8.08,8.25,8.208333333333334,8.833333333333334,9.742857142857144],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666 ...

# %% [markdown]
# ## Q3: Sampling Effort

# %%
samples_by_station = (
    merged.groupby("station_id", as_index=False)
    .agg(count=("result", "count"))
    .sort_values("count", ascending=False)
)

samples_by_station.head()
# Out:
#       station_id  count
# 3             12   2249
# 1318       45929   1822
# 1319       45935   1781
# 1             10   1606
# 1317       45927   1447

# %% [markdown]
# ## Q4: Parameter Correlation

# %%
# Make a pivot table so each parameter becomes its own column
pivot = merged.pivot_table(
    index=["station_id", "sample_date"],
    columns="parameter",
    values="result",
    aggfunc="mean"
).reset_index()

# See what parameter columns we actually have after pivot
print("Pivot columns:", pivot.columns.tolist())

# Make sure we only use parameters that exist as columns
params = ["pH", "DissolvedOxygen", "ElectricalConductance"]
existing_params = [p for p in params if p in pivot.columns]

print("Using these parameters for correlation:", existing_params)

corr_matrix = pivot[existing_params].corr()
corr_matrix
# Out:
# Pivot columns: ['station_id', 'sample_date', 'DissolvedOxygen', 'ElectricalConductance', 'pH']
# Using these parameters for correlation: ['pH', 'DissolvedOxygen', 'ElectricalConductance']
# parameter                    pH  DissolvedOxygen  ElectricalConductance
# parameter
# pH                     1.000000        -0.000992               0.570200
# DissolvedOxygen       -0.000992         1.000000              -0.053621
# ElectricalConductance  0.570200        -0.053621               1.000000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This notebook used real California water quality data to explore:
#
# - Average values by station
# - Trends over time
# - Sampling effort
# - Basic correlations between parameters
#
# All analysis used tools from class: filtering, groupby, merging, summary statistics, and basic plotting.
