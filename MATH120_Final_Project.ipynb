# %% [markdown]
# <a href="https://colab.research.google.com/github/haydenmclemore-fresnost/math120_final_project/blob/main/MATH120_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # California Water Quality Analysis – Final Project
# This notebook analyzes selected water quality measurements from the California Department of Water Resources (DWR).
# The goal is to clean the data, merge it with station information, and answer a few basic questions using tools from class.

# %% [markdown]
# ## Environment Setup/Loading Data

# %% [markdown]
# This notebook loads raw data directly from the repository so it can be run by anyone who downloads or clones the project.

# %%
import os
REPO_URL = "https://github.com/haydenmclemore-fresnost/math120_final_project.git"
REPO_DIR = "math120_final_project"
if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL}
# %cd {REPO_DIR}
# Out:
# Cloning into 'math120_final_project'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 86 (delta 25), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 1.78 MiB | 4.26 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# /content/math120_final_project/math120_final_project/math120_final_project

# %%
# Load raw data from the repo
import pandas as pd
stations = pd.read_csv("data_raw/stations_raw.csv")
field = pd.read_csv("data_raw/field_results_raw_sample.csv")
print(stations.shape)
print(field.shape)
stations.head(), field.head()
# Out:
# (44630, 12)
# (50000, 23)
# (   _id  station_id     station_name         full_station_name station_number  \
#  0    1       47023  Frank Sieferman  Frank Sieferman New Well  01N01E01A001M
#  1    2        6134    01N01E33K001M             01N01E33K001M  01N01E33K001M
#  2    3        6135    01N01W03N001M             01N01W03N001M  01N01W03N001M
#  3    4        6136    01N01W04A001M             01N01W04A001M  01N01W04A001M
#  4    5        6137    01N01W07K001M             01N01W07K001M  01N01W07K001M
#
#    station_type  latitude  longitude   county_name  sample_count  \
#  0  Groundwater   33.0000  -121.0000          Yolo             1
#  1  Groundwater   37.8868  -121.8682  Contra Costa             1
#  2  Groundwater   37.9583  -121.9669  Contra Costa             9
#  3  Groundwater   37.9663  -121.9734  Contra Costa             9
#  4  Groundwater   37.9460  -122.0155  Contra Costa             9
#
#         sample_date_min      sample_date_max
#  0  2008-06-23T15:00:00  2008-06-23T15:00:00
#  1  1981-05-20T13:45:00  1981-05-20T13:45:00
#  2  1974-07-23T15:15:00  1990-08-16T12:15:00
#  3  1972-08-04T15:00:00  1989-09-15T08:00:00
#  4  1973-08-03T09:30:00  1989-09-15T09:15:00  ,
#     _id  station_id          station_name station_number  \
#  0    1          12  H.O. Banks Headworks       KA000331
#  1    2          12  H.O. Banks Headworks       KA000331
#  2    3          12  H.O. Banks Headworks       KA000331
#  3    4          12  H.O. Banks Headworks       KA000331
#  4    5          12  H.O. Banks Headworks       KA000331
#
#                         full_station_name   station_type  latitude  longitude  \
#  0  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
#  1  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
#  2  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
#  3  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
#  4  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
#
#                            status county_name  sample_code  \
#  0  Public, Review Status Unknown     Alameda  OM0168A0001
#  1  Public, Review Status Unknown     Alameda  OM0168A0001
#  2  Public, Review Status Unknown     Alameda  OM0168A0001
#  3  Public, Review Status Unknown     Alameda  OM0168A0001
#  4  Public, Review Status Unknown     Alameda  OM0268A0006
#
#             sample_date  sample_depth sample_depth_units anl_data_type  \
#  0  1968-01-04T07:45:00           1.0               Feet           NaN
#  1  1968-01-04T07:45:00           1.0               Feet           NaN
#  2  1968-01-04T07:45:00           1.0               Feet           NaN
#  3  1968-01-04T07:45:00           1.0               Feet           NaN
#  4  1968-02-01T08:10:00           1.0               Feet           NaN
#
#                 parameter  fdr_result fdr_text_result fdr_date_result  \
#  0        DissolvedOxygen         9.2             NaN             NaN
#  1  ElectricalConductance       515.0             NaN             NaN
#  2       WaterTemperature         6.7             NaN             NaN
#  3                     pH         7.3             NaN             NaN
#  4        DissolvedOxygen         9.7             NaN             NaN
#
#     fdr_reporting_limit  uns_name                   mth_name fdr_footnote
#  0                  0.2      mg/L          EPA 360.2 (Field)          NaN
#  1                  1.0     uS/cm  Std Method 2510-B (Field)          NaN
#  2                  0.1        °C          EPA 170.1 (Field)          NaN
#  3                  0.1  pH Units          EPA 150.1 (Field)          NaN
#  4                  0.2      mg/L          EPA 360.2 (Field)          NaN  )

# %% [markdown]
# ## Import Libraries (The rest of them)

# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
pd.set_option("display.max_columns", 50)

# %% [markdown]
# ## Clean and Standardize Columns

# %%
# Make a numeric result column from fdr_result
field["result"] = field["fdr_result"]
# Ensure sample_date is datetime
field["sample_date"] = pd.to_datetime(field["sample_date"], errors="coerce")
field.head()
# Out:
#    _id  station_id          station_name station_number  \
# 0    1          12  H.O. Banks Headworks       KA000331
# 1    2          12  H.O. Banks Headworks       KA000331
# 2    3          12  H.O. Banks Headworks       KA000331
# 3    4          12  H.O. Banks Headworks       KA000331
# 4    5          12  H.O. Banks Headworks       KA000331
#
#                        full_station_name   station_type  latitude  longitude  \
# 0  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 1  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 2  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 3  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 4  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
#
#                           status county_name  sample_code         sample_date  \
# 0  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00
# 1  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00
# 2  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00
# 3  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00
# 4  Public, Review Status Unknown     Alameda  OM0268A0006 1968-02-01 08:10:00
#
#    sample_depth sample_depth_units anl_data_type              parameter  \
# 0           1.0               Feet           NaN        DissolvedOxygen
# 1           1.0               Feet           NaN  ElectricalConductance
# 2           1.0               Feet           NaN       WaterTemperature
# 3           1.0               Feet           NaN                     pH
# 4           1.0               Feet           NaN        DissolvedOxygen
#
#    fdr_result fdr_text_result fdr_date_result  fdr_reporting_limit  uns_name  \
# 0         9.2             NaN             NaN                  0.2      mg/L
# 1       515.0             NaN             NaN                  1.0     uS/cm
# 2         6.7             NaN             NaN                  0.1        °C
# 3         7.3             NaN             NaN                  0.1  pH Units
# 4         9.7             NaN             NaN                  0.2      mg/L
#
#                     mth_name fdr_footnote  result
# 0          EPA 360.2 (Field)          NaN     9.2
# 1  Std Method 2510-B (Field)          NaN   515.0
# 2          EPA 170.1 (Field)          NaN     6.7
# 3          EPA 150.1 (Field)          NaN     7.3
# 4          EPA 360.2 (Field)          NaN     9.7

# %% [markdown]
# ## Filter to Selected Water Quality Parameters

# %%
params = ["pH", "DissolvedOxygen", "ElectricalConductance"]
field_sub = field[field["parameter"].isin(params)]
field_sub.head()
# Out:
#    _id  station_id          station_name station_number  \
# 0    1          12  H.O. Banks Headworks       KA000331
# 1    2          12  H.O. Banks Headworks       KA000331
# 3    4          12  H.O. Banks Headworks       KA000331
# 4    5          12  H.O. Banks Headworks       KA000331
# 5    6          12  H.O. Banks Headworks       KA000331
#
#                        full_station_name   station_type  latitude  longitude  \
# 0  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 1  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 3  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 4  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
# 5  Delta P.P. Headworks at H.O. Banks PP  Surface Water   37.8019  -121.6203
#
#                           status county_name  sample_code         sample_date  \
# 0  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00
# 1  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00
# 3  Public, Review Status Unknown     Alameda  OM0168A0001 1968-01-04 07:45:00
# 4  Public, Review Status Unknown     Alameda  OM0268A0006 1968-02-01 08:10:00
# 5  Public, Review Status Unknown     Alameda  OM0268A0006 1968-02-01 08:10:00
#
#    sample_depth sample_depth_units anl_data_type              parameter  \
# 0           1.0               Feet           NaN        DissolvedOxygen
# 1           1.0               Feet           NaN  ElectricalConductance
# 3           1.0               Feet           NaN                     pH
# 4           1.0               Feet           NaN        DissolvedOxygen
# 5           1.0               Feet           NaN  ElectricalConductance
#
#    fdr_result fdr_text_result fdr_date_result  fdr_reporting_limit  uns_name  \
# 0         9.2             NaN             NaN                  0.2      mg/L
# 1       515.0             NaN             NaN                  1.0     uS/cm
# 3         7.3             NaN             NaN                  0.1  pH Units
# 4         9.7             NaN             NaN                  0.2      mg/L
# 5       720.0             NaN             NaN                  1.0     uS/cm
#
#                     mth_name fdr_footnote  result
# 0          EPA 360.2 (Field)          NaN     9.2
# 1  Std Method 2510-B (Field)          NaN   515.0
# 3          EPA 150.1 (Field)          NaN     7.3
# 4          EPA 360.2 (Field)          NaN     9.7
# 5  Std Method 2510-B (Field)          NaN   720.0

# %% [markdown]
# ## Merge Field Data With Station Metadata

# %%
merged = field_sub.merge(stations, on="station_id", how="left")
merged.head()
# Out:
#    _id_x  station_id        station_name_x station_number_x  \
# 0      1          12  H.O. Banks Headworks         KA000331
# 1      2          12  H.O. Banks Headworks         KA000331
# 2      4          12  H.O. Banks Headworks         KA000331
# 3      5          12  H.O. Banks Headworks         KA000331
# 4      6          12  H.O. Banks Headworks         KA000331
#
#                      full_station_name_x station_type_x  latitude_x  \
# 0  Delta P.P. Headworks at H.O. Banks PP  Surface Water     37.8019
# 1  Delta P.P. Headworks at H.O. Banks PP  Surface Water     37.8019
# 2  Delta P.P. Headworks at H.O. Banks PP  Surface Water     37.8019
# 3  Delta P.P. Headworks at H.O. Banks PP  Surface Water     37.8019
# 4  Delta P.P. Headworks at H.O. Banks PP  Surface Water     37.8019
#
#    longitude_x                         status county_name_x  sample_code  \
# 0    -121.6203  Public, Review Status Unknown       Alameda  OM0168A0001
# 1    -121.6203  Public, Review Status Unknown       Alameda  OM0168A0001
# 2    -121.6203  Public, Review Status Unknown       Alameda  OM0168A0001
# 3    -121.6203  Public, Review Status Unknown       Alameda  OM0268A0006
# 4    -121.6203  Public, Review Status Unknown       Alameda  OM0268A0006
#
#           sample_date  sample_depth sample_depth_units anl_data_type  \
# 0 1968-01-04 07:45:00           1.0               Feet           NaN
# 1 1968-01-04 07:45:00           1.0               Feet           NaN
# 2 1968-01-04 07:45:00           1.0               Feet           NaN
# 3 1968-02-01 08:10:00           1.0               Feet           NaN
# 4 1968-02-01 08:10:00           1.0               Feet           NaN
#
#                parameter  fdr_result fdr_text_result fdr_date_result  \
# 0        DissolvedOxygen         9.2             NaN             NaN
# 1  ElectricalConductance       515.0             NaN             NaN
# 2                     pH         7.3             NaN             NaN
# 3        DissolvedOxygen         9.7             NaN             NaN
# 4  ElectricalConductance       720.0             NaN             NaN
#
#    fdr_reporting_limit  uns_name                   mth_name fdr_footnote  \
# 0                  0.2      mg/L          EPA 360.2 (Field)          NaN
# 1                  1.0     uS/cm  Std Method 2510-B (Field)          NaN
# 2                  0.1  pH Units          EPA 150.1 (Field)          NaN
# 3                  0.2      mg/L          EPA 360.2 (Field)          NaN
# 4                  1.0     uS/cm  Std Method 2510-B (Field)          NaN
#
#    result    _id_y        station_name_y  \
# 0     9.2  43682.0  H.O. Banks Headworks
# 1   515.0  43682.0  H.O. Banks Headworks
# 2     7.3  43682.0  H.O. Banks Headworks
# 3     9.7  43682.0  H.O. Banks Headworks
# 4   720.0  43682.0  H.O. Banks Headworks
#
#                      full_station_name_y station_number_y station_type_y  \
# 0  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water
# 1  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water
# 2  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water
# 3  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water
# 4  Delta P.P. Headworks at H.O. Banks PP         KA000331  Surface Water
#
#    latitude_y  longitude_y county_name_y  sample_count      sample_date_min  \
# 0     37.8019    -121.6203       Alameda        1720.0  1960-10-16T07:25:00
# 1     37.8019    -121.6203       Alameda        1720.0  1960-10-16T07:25:00
# 2     37.8019    -121.6203       Alameda        1720.0  1960-10-16T07:25:00
# 3     37.8019    -121.6203       Alameda        1720.0  1960-10-16T07:25:00
# 4     37.8019    -121.6203       Alameda        1720.0  1960-10-16T07:25:00
#
#        sample_date_max
# 0  2025-10-21T11:35:00
# 1  2025-10-21T11:35:00
# 2  2025-10-21T11:35:00
# 3  2025-10-21T11:35:00
# 4  2025-10-21T11:35:00

# %% [markdown]
# ## Q1: Average Values by Station

# %%
station_summary = (
    merged.groupby(["station_id", "parameter"], as_index=False)
    .agg(avg=("result", "mean"), count=("result", "count"))
)
station_summary.head()
# Out:
#    station_id              parameter         avg  count
# 0          12        DissolvedOxygen    9.659867   1054
# 1          12  ElectricalConductance  356.512821    117
# 2          12                     pH    7.718998   1078
# 3          15        DissolvedOxygen    7.442857      7
# 4          15                     pH    7.900000      5

# %% [markdown]
# ## Q2: Trend Over Time (Example Station)

# %%
merged = merged.dropna(subset=["sample_date"])
merged["year"] = merged["sample_date"].dt.year
do_data = merged[merged["parameter"] == "DissolvedOxygen"]
do_data["station_id"].value_counts().head()
# Out:
# station_id
# 12      1054
# 422      641
# 373      550
# 397      546
# 1102     529
# Name: count, dtype: int64

# %%
top_station = do_data["station_id"].value_counts().idxmax()
top_station
yearly = (
    do_data[do_data["station_id"] == top_station]
    .groupby("year", as_index=False)
    .agg(avg=("result", "mean"))
)
px.line(yearly, x="year", y="avg", title=f"Dissolved Oxygen Over Time (Station {top_station})")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bb2ffbbc-128f-448a-aaee-6cc8341faecd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb2ffbbc-128f-448a-aaee-6cc8341faecd")) {                    Plotly.newPlot(                        "bb2ffbbc-128f-448a-aaee-6cc8341faecd",                        [{"hovertemplate":"year=%{x}\u003cbr\u003eavg=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[8.175675675675675,8.348936170212765,8.784615384615385,8.763636363636364,8.983333333333333,9.018181818181818,9.028571428571428,8.838461538461539,9.583333333333334,10.786666666666667,10.1,8.923076923076923,10.058333333333334,9.091666666666667,9.222222222222221,8.670370370370371,9.36216216216216,9.104,8.98695652173913,9.458333333333334,9.152000000000001,9.463636363636365,8.735,8.723333333333333,8.718181818181819,8.353333333333333,8.765384615384615,8.347999999999999,8.484827586206897,8.39,8.6,9.236363636363636,9.07,8.3375,8.489999999999998,7.8500000000000005,8.27142857142857,77.47500000000001,8.385714285714286,8.666666666666666,9.166666666666666,8.96,9.175217391304347,9.212916666666667,9.279166666666667,10.225,9.008333333333333,9.56,9.454545454545455,8.316666666666666,7.483333333333333,8.057142857142857,7.75,8.08,8.25,8.208333333333334,8.833333333333334,9.742857142857144],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666 ...

# %% [markdown]
# ## Q3: Sampling Effort

# %%
samples_by_station = (
    merged.groupby("station_id", as_index=False)
    .agg(count=("result", "count"))
    .sort_values("count", ascending=False)
)
samples_by_station.head()
# Out:
#     station_id  count
# 0           12   2249
# 21         422   1309
# 17         397   1133
# 13         373   1115
# 51        1102   1055

# %% [markdown]
# ## Q4: Parameter Correlation

# %%
# Make a pivot table so each parameter becomes its own column
pivot = merged.pivot_table(
    index=["station_id", "sample_date"],
    columns="parameter",
    values="result",
    aggfunc="mean"
).reset_index()
# See what parameter columns we actually have after pivot
print("Pivot columns:", pivot.columns.tolist())
# Make sure we only use parameters that exist as columns
params = ["pH", "DissolvedOxygen", "ElectricalConductance"]
existing_params = [p for p in params if p in pivot.columns]
print("Using these parameters for correlation:", existing_params)
corr_matrix = pivot[existing_params].corr()
corr_matrix
# Out:
# Pivot columns: ['station_id', 'sample_date', 'DissolvedOxygen', 'ElectricalConductance', 'pH']
# Using these parameters for correlation: ['pH', 'DissolvedOxygen', 'ElectricalConductance']
# parameter                    pH  DissolvedOxygen  ElectricalConductance
# parameter
# pH                     1.000000        -0.001540               0.590631
# DissolvedOxygen       -0.001540         1.000000              -0.025764
# ElectricalConductance  0.590631        -0.025764               1.000000

# %%
# Save cleaned dataset used for analysis
merged.to_csv("../data/merged_cleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-3202676039.py in <cell line: 0>()
#       1 # Save cleaned dataset used for analysis
# ----> 2 merged.to_csv("../data/merged_cleaned.csv", index=False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: '../data'

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This notebook used real California water quality data to explore:
#
# - Average values by station
# - Trends over time
# - Sampling effort
# - Basic correlations between parameters
